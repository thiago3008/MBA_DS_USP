# %% [markdown]
# # Aula 7: Classificação - Árvores e avaliação

# %% [markdown]
# Francisco Aparecido Rodrigues, francisco@icmc.usp.br.<br>
# Universidade de São Paulo, São Carlos, Brasil.<br>
# Copyright (c) 2020.

# %% [markdown]
# <hr>

# %% [markdown]
# Vamos inicialmente lendo os dados:

# %%
import random
random.seed(42) # define the seed (important to reproduce the results)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('../data/Vehicle.csv', header=(0))

# remove NaN
data = data.dropna(axis='rows') #
# armazena o nome das classes
classes = np.array(pd.unique(data[data.columns[-1]]), dtype=str)  #name of the clases
features_names = data.columns

print("Número de linhas e colunas na matriz de atributos:", data.shape)
attributes = list(data.columns[0:-2])
# mostra os dados
data.head(10)
# Out:
# Número de linhas e colunas na matriz de atributos: (846, 19)
#    Comp  Circ  D.Circ  Rad.Ra  Pr.Axis.Ra  Max.L.Ra  Scat.Ra  Elong  \
# 0    95    48      83     178          72        10      162     42
# 1    91    41      84     141          57         9      149     45
# 2   104    50     106     209          66        10      207     32
# 3    93    41      82     159          63         9      144     46
# 4    85    44      70     205         103        52      149     45
# 5   107    57     106     172          50         6      255     26
# 6    97    43      73     173          65         6      153     42
# 7    90    43      66     157          65         9      137     48
# 8    86    34      62     140          61         7      122     54
# 9    93    44      98     197          62        11      183     36
#
#    Pr.Axis.Rect  Max.L.Rect  Sc.Var.Maxis  Sc.Var.maxis  Ra.Gyr  Skew.Maxis  \
# 0            20         159           176           379     184          70
# 1            19         143           170           330     158          72
# 2            23         158           223           635     220          73
# 3            19         143           160           309     127          63
# 4            19         144           241           325     188         127
# 5            28         169           280           957     264          85
# 6            19         143           176           361     172          66
# 7            18         146           162           281     164          67
# 8            17         127           141           223     112          64
# 9            22         146           202           505     152          64
#
#    Skew.maxis  Kurt.maxis  Kurt.Maxis  Holl.Ra Class
# 0           6          16         187      197   van
# 1           9          14         189      199   van
# 2          14           9         188      196  saab
# 3           6          10         199      207   van
# 4           9          11         180      183   bus
# 5           5           9         181      183   bus
# 6          13           1         200      204   bus
# 7           3           3         193      202   van
# 8           2          14         200      208   van
# 9           4          14         195      204  saab

# %% [markdown]
# Construímos as variáveis $X$ e $y$, sendo que o processo de classificação se resume em estimar a função $f$ na relação $y = f(X) + \epsilon$, onde $\epsilon$ é o erro, que tem distribuição normal com média igual a zero e variância $\sigma^2$.

# %% [markdown]
# Convertemos para o formato Numpy pra facilitar a manipulação dos dados.

# %%
data = data.to_numpy()
nrow,ncol = data.shape
y = data[:,-1]
X = data[:,0:ncol-1]

# %% [markdown]
# Para treinar o classificador, precisamos definir o conjunto de teste e treinamento.

# %%
from sklearn.model_selection import train_test_split
p = 0.2 # fracao de elementos no conjunto de teste
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = p, random_state = 2)

# %% [markdown]
# A partir desse conjunto de dados, podemos realizar a classificação.

# %% [markdown]
# ## Árvores de decisão

# %% [markdown]
# Árvores de decisão podem ser construidas de diferentes formas, considerando diferentes métodos e medidas, como vimos na aula. Vamos inicialmente construir a árvore usando o critério Gini:

# %%
from sklearn import tree
# Cria o modelo usando o criterio Gini
model = tree.DecisionTreeClassifier(criterion = 'gini', random_state = 101)
# Ajusta o modelo usando os dados de treinamento
model.fit(x_train,y_train)
# realizar a predição
y_pred = model.predict(x_test)

# %% [markdown]
# Usando a medida de acurácia, avaliamos o desempenho do modelo no aprendizado.

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_pred, y_test)
print('Accuracy:', score)
# Out:
# Accuracy: 0.7058823529411765

# %% [markdown]
# Podemos visualizar a árvore.

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(model.fit(x_train,y_train),filled=True)
#plt.savefig('tree.pdf', dpi=1200)
plt.show(True)

# %% [markdown]
# Se usarmos a medida de entropia:

# %%
from sklearn import tree
from sklearn.metrics import accuracy_score

model = tree.DecisionTreeClassifier(criterion = 'entropy',random_state = 101)
model.fit(x_train,y_train)
y_pred = model.predict(x_test) 

score = accuracy_score(y_pred, y_test)
print('Accuracy:', score)
# Out:
# Accuracy: 0.7588235294117647

# %% [markdown]
# Mostrando a respectiva árvore.

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(model.fit(x_train,y_train), filled=True) 
plt.show(True)

# %% [markdown]
# Podemos também limitar o tamanho da árvore, o que influencia no resultado:

# %%
from sklearn import tree
from sklearn.metrics import accuracy_score

# cria o modelo com número máximo de níveis max_depth
model = tree.DecisionTreeClassifier(criterion = 'entropy', max_depth = 2)
# ajusta aos dados de treinamento
model.fit(x_train,y_train)
# faz a predição usando os dados de teste
y_pred = model.predict(x_test) 
# calcula a acurácia
score = accuracy_score(y_pred, y_test)
print('Accuracy:', score)
# Out:
# Accuracy: 0.5470588235294118

# %% [markdown]
# Visualizando a estrutura da árvore, vemos que há menos níveis do que a anterior.

# %%
plt.figure(figsize=(10,6))
tree.plot_tree(model.fit(x_train,y_train),filled=True) 
plt.show(True)

# %% [markdown]
# Veja a implementação original e estude os parâmetros do modelo: https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html

# %% [markdown]
# ## Florestas aleatórias

# %% [markdown]
# O método florestas aleatórias considera amostragem de observações e atributos. Vamos realizar a classificação.

# %%
from sklearn.ensemble import RandomForestClassifier

# define os parâmetros do modelo
model=RandomForestClassifier(n_estimators=100, bootstrap=True, class_weight=None, criterion='gini',
            max_depth=None, max_features='auto', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=1, min_samples_split=2,
            min_weight_fraction_leaf=0.0, n_jobs=1,
            oob_score=False, random_state=None, verbose=0,
            warm_start=False)
model.fit(x_train,y_train)

#Predict the response for test dataset
y_pred = model.predict(x_test)
score = accuracy_score(y_pred, y_test)
print('Accuracy:', score)
# Out:
# Accuracy: 0.7705882352941177

# %% [markdown]
# Estudo os atributos do método: https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html

# %% [markdown]
# Podemos analisar como o número de árvores influencia no resultado.

# %%
vscore = []
vn = []
for n in range(1,100,5):
    model = RandomForestClassifier(n_estimators=n)
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test) 
    score = accuracy_score(y_pred, y_test)
    print('Number of Estimators:', n, 'Accuracy:', score)
    vscore.append(score)
    vn.append(n)
best_n = vn[np.argmax(vscore)]
print('Melhor n:', best_n, ' com acurácia:', vscore[np.argmax(vscore)] )
plt.figure(figsize=(10,5))
plt.plot(vn, vscore, '-bo')
plt.xlabel('Number of Estimators', fontsize = 15)
plt.ylabel('Accuracy', fontsize = 15)
plt.show()
# Out:
# Number of Estimators: 1 Accuracy: 0.7176470588235294
# Number of Estimators: 6 Accuracy: 0.7470588235294118
# Number of Estimators: 11 Accuracy: 0.7176470588235294
# Number of Estimators: 16 Accuracy: 0.7411764705882353
# Number of Estimators: 21 Accuracy: 0.7941176470588235
# Number of Estimators: 26 Accuracy: 0.7764705882352941
# Number of Estimators: 31 Accuracy: 0.8
# Number of Estimators: 36 Accuracy: 0.7647058823529411
# Number of Estimators: 41 Accuracy: 0.7705882352941177
# Number of Estimators: 46 Accuracy: 0.788235294117647
# Number of Estimators: 51 Accuracy: 0.7823529411764706
# Number of Estimators: 56 Accuracy: 0.788235294117647
# Number of Estimators: 61 Accuracy: 0.7764705882352941
# Number of Estimators: 66 Accuracy: 0.7705882352941177
# Number of Estimators: 71 Accuracy: 0.7823529411764706
# Number of Estimators: 76 Accuracy: 0.7941176470588235
# Number of Estimators: 81 Accuracy: 0.7529411764705882
# Number of Estimators: 86 Accuracy: 0.7823529411764706
# Number of Estimators: 91 Accuracy: 0.7705882352941177
# Number of Estimators: 96 Accuracy: 0.7647058823529411
# Melhor n: 31  com acurácia: 0.8

# %% [markdown]
# #### O algoritmo random forest permite ainda quantificar a importância de cada variável na classificação. Quanto maior esse valor, mais o atributo influencia na classificação. Vejam que a soma dos pesos é igual a um.

# %%
importances = model.feature_importances_
indices = np.argsort(importances)
lmeas_order = []
for i in indices:
    lmeas_order.append(features_names[i])
plt.figure(figsize=(12,8))
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), lmeas_order, fontsize=15)
plt.xlabel('Relative Importance',fontsize=15)
plt.xticks(color='k', size=20)
plt.yticks(color='k', size=20)
plt.show()

# %% [markdown]
# Com isso, podemos fazer uma ordenação dos atributos e selecionar apenas os mais importantes.

# %% [markdown]
# ## Avaliação de classificadores

# %% [markdown]
# Inicialmente, vamos considerar uma base com apenas duas classes.

# %%
import random
random.seed(1) # define the seed (important to reproduce the results)
# Pandas is used for data manipulation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# CSV file
features = pd.read_csv('../data/vertebralcolumn-2C.csv', header=(0))
features = features.dropna(axis='rows') #remove NaN
classes = pd.unique(features[features.columns[-1]]) #name of the clases
classes = np.array(classes, dtype=str) # convert to an array

print(features.shape)
feature_names = list(features.columns)
features.head(10)
# Out:
# (310, 7)
#    pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027817    22.552586              39.609117     40.475232
# 1         39.056951    10.060991              25.015378     28.995960
# 2         68.832021    22.218482              50.092194     46.613539
# 3         69.297008    24.652878              44.311238     44.644130
# 4         49.712859     9.652075              28.317406     40.060784
# 5         40.250200    13.921907              25.124950     26.328293
# 6         53.432928    15.864336              37.165934     37.568592
# 7         45.366754    10.755611              29.038349     34.611142
# 8         43.790190    13.533753              42.690814     30.256437
# 9         36.686353     5.010884              41.948751     31.675469
#
#    pelvic_radius  degree_spondylolisthesis     class
# 0      98.672917                 -0.254400  Abnormal
# 1     114.405425                  4.564259  Abnormal
# 2     105.985135                 -3.530317  Abnormal
# 3     101.868495                 11.211523  Abnormal
# 4     108.168725                  7.918501  Abnormal
# 5     130.327871                  2.230652  Abnormal
# 6     120.567523                  5.988551  Abnormal
# 7     117.270067                -10.675871  Abnormal
# 8     125.002893                 13.289018  Abnormal
# 9      84.241415                  0.664437  Abnormal

# %%
Y = np.array(features[list(features.columns)[-1]],dtype=str)

# Remove the labels from the features
# axis 1 refers to the columns
features= features.drop(list(features.columns)[-1], axis = 1)

# Saving feature names for later use
feature_list = list(features.columns)

# Convert to numpy array
X = np.array(features)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X)
X = scaler.transform(X)

# %%
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
p = 0.8
train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size = 1-p, random_state = 42)

# %% [markdown]
# #### Vamos considerar um método de classificação e obter a predição das classes.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
clf = RandomForestClassifier(n_estimators = 50)
clf.fit(train_x, train_y)
# Out:
# RandomForestClassifier(n_estimators=50)

# %%
pred_y = clf.predict(test_x)

# %% [markdown]
# Com a predição, podemos fazer a avaliação dos resultados usando diferentes métricas.

# %% [markdown]
# A acurácia é dada pela fração de elementos classificados corretamente.

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(pred_y, test_y)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.7903225806451613

# %% [markdown]
# A matriz de confusão permite verificar a relação entre as classes preditos e os originais.

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(pred_y, test_y)
pd.crosstab(pred_y, test_y, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# Predicted  Abnormal  Normal  All
# True
# Abnormal         40       9   49
# Normal            4       9   13
# All              44      18   62

# %% [markdown]
# Há diversas outras métricas que podem quantificar a qualidade de uma classificação.

# %%
from sklearn.metrics import precision_score, recall_score, classification_report, accuracy_score, f1_score

print('Accuracy:', accuracy_score(pred_y, test_y))
print('F1 score:', f1_score(test_y, pred_y, average="macro"))
print('Precision:', precision_score(test_y, pred_y, average="macro"))
print('Recall:', recall_score(test_y, pred_y, average="macro"))
print('\n clasification report:\n', classification_report(test_y, pred_y))
# Out:
# Accuracy: 0.7903225806451613
# F1 score: 0.7204301075268817
# Precision: 0.7543171114599686
# Recall: 0.7045454545454546
#
#  clasification report:
#                precision    recall  f1-score   support
#
#     Abnormal       0.82      0.91      0.86        44
#       Normal       0.69      0.50      0.58        18
#
#     accuracy                           0.79        62
#    macro avg       0.75      0.70      0.72        62
# weighted avg       0.78      0.79      0.78        62

# %% [markdown]
# ### Exercícios de fixação

# %% [markdown]
# Não é necessário entregar os exercícios abaixo, mas é importante resolvê-los para fixar os conteúdos estudados.

# %% [markdown]
# 1 - Repita todos os passos acima para a base de dados BreastCancer.

# %% [markdown]
# 2 - Considerando a base de dados Vehicle, calcule as métricas de avaliação vistas nessa aula para os classificadores árvores de decisão e florestas aleatórias.

# %% [markdown]
# 3 - Faça a classificação dos dados gerados artificialmente com o código abaixo. Compare os resultados para os métodos vistos nessa aula.

# %%
from sklearn import datasets
plt.figure(figsize=(6,4))

n_samples = 1000

data  = datasets.make_moons(n_samples=n_samples, noise=.15)
X = data[0]
y = data[1]
plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', s=50, alpha=0.7)
plt.show(True)
