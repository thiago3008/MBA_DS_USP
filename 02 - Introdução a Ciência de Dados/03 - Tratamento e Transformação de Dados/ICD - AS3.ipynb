# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt

# %% [markdown]
# ## (5) Quantas variáveis são necessárias para se explicar ao menos 90% da variância nos dados Vehicle? <br>
# ```py
# a) 5
# b) 2
# c) 8
# d) 10
# e) 1
# ```

# %%
# Importar base de dados 'Vehicle.csv'
data = pd.read_csv('data\Vehicle.csv', header=(0))

# %%
data = data.to_numpy()
print(data)
# Out:
# [[95 48 83 ... 187 197 'van']
#  [91 41 84 ... 189 199 'van']
#  [104 50 106 ... 188 196 'saab']
#  ...
#  [106 54 101 ... 187 201 'saab']
#  [86 36 78 ... 190 195 'saab']
#  [85 36 66 ... 186 190 'van']]

# %%
nrow, ncol = data.shape
print(f'Número de linhas: {nrow}\nNúmero de colunas: {ncol}')
# Out:
# Número de linhas: 846
# Número de colunas: 19

# %% [markdown]
# ### Variáveis X representa os atributos e Y as classes.

# %%
X = data[:,0:ncol-1]

# %% [markdown]
# ### Padronização dos dados, de modo a evitar o efeito da escala dos atributos.

# %%
# realiza a padronização (média=0, variância = 1)
scaler = StandardScaler().fit(X)
X = scaler.transform(X)

# %% [markdown]
# ### Análise dos componentes principais

# %% [markdown]
# Para estimarmos o número de componentes para projetarmos os dados, podemos analisar como a variância muda de acordo com o número de componentes.

# %%
pca = PCA().fit(X)

plt.figure(figsize=(8,5))
ncomp = np.arange(1, np.shape(X)[1]+1)

# mostra a variância acumulada
plt.plot(ncomp, np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('number of components', fontsize=20)
plt.ylabel('cumulative explained variance', fontsize=20);
plt.xticks(color='k', size=20)
plt.yticks(color='k', size=20)
plt.grid(True)
plt.show(True)
